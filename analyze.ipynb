# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')

# %%
df.head()
# Out:
#    ObjectId                       Country ISO2    ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF     AFG
# 1         2                        Africa  NaN  AFRTMP
# 2         3                       Albania   AL     ALB
# 3         4                       Algeria   DZ     DZA
# 4         5                American Samoa   AS     ASM
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
highest = df.loc[idx, ['Country','2024']]
print(f"The highest units value is: {highest}")
# Out:
# The highest units value is: Country    Svalbard Jan Mayen Islands
# 2024                            3.689
# Name: 196, dtype: object

# %%
df.tail()
# Out:
#      ObjectId         Country ISO2 ISO3  \
# 226       232  Western Sahara   EH  ESH
# 227       233           World  NaN  WLD
# 228       234  Yemen, Rep. of   YE  YEM
# 229       235          Zambia   ZM  ZMB
# 230       236        Zimbabwe   ZW  ZWE
#
#                                              Indicator            Unit  \
# 226  Temperature change with respect to a baseline ...  Degree Celsius
# 227  Temperature change with respect to a baseline ...  Degree Celsius
# 228  Temperature change with respect to a baseline ...  Degree Celsius
# 229  Temperature change with respect to a baseline ...  Degree Celsius
# 230  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                                 Source CTS Code  \
# 226  Food and Agriculture Organization of the Unite...     ECCS
# 227  Food and Agriculture Organization of the Unite...     ECCS
# 228  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')
df = df.set_index('Country')

top20 = df.sort_values(by='2024', ascending=False).head(20)


top20.plot(kind='bar', y='2024', color=colors, title='Top 20: Annual Mean Global Surface Temperature in 2024')
plt.xlabel('Country')
plt.ylabel('Temperature (°C)')
plt.show()

low20 = df.sort_values(by='2024', ascending=False).tail(20)
low20.plot(kind='bar', y='2024', color=colors, title='Lowest 20: Annual Mean Global Surface Temperature in 2024')
plt.xlabel('Country')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')
df = df.set_index('Country')

top20 = df.sort_values(by='2024', ascending=False).head(20)


top20.plot(kind='bar', y='2024', color=colors, title='Top 20: Annual Mean Global Surface Temperature in 2024')
plt.xlabel('Country')
plt.ylabel('Temperature (°C)')
plt.show()

low20 = df.sort_values(by='2024', ascending=False).tail(20)
low20.plot(kind='bar', y='2024', color=colors, title='Lowest 20: Annual Mean Global Surface Temperature in 2024')
plt.xlabel('Country')
plt.ylabel('Temperature (°C)')
plt.show()

# %%
df.Countrys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5y/7khdqqpd6931c5q7rjmhk2s00000gn/T/ipykernel_24437/1003040684.py in ?()
# ----> 1 df.Countrys()
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Countrys'

# %%
df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')
df['diff'] = df['2024'] - df['1961']
top_diff = df.sort_values(by='diff', ascending=False).head(10)

fig, ax = plt.subplots()
index = np.arange(len(top_diff))
bar_width = 0.35

start = ax.bar(index, top_diff['1961'], bar_width, color= "Blue", label="1961")
end = ax.bar(index + bar_width, top_diff['2024'], bar_width, color="Purple", label="2024")

ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(top_diff['Country'], rotation=45, ha='right')

ax.set_xlabel('Country')
ax.set_ylabel('Temperature (°C)')
ax.set_title('Top 10 Countries: Temperature Increase (1961 vs 2024)')
ax.legend()

plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')
df['diff'] = df['2024'] - df['1961']
top_diff = df.sort_values(by='diff', ascending=False).head(10)

fig, ax = plt.subplots()
index = np.arange(len(top_diff))
bar_width = 0.35

start = ax.bar(index, top_diff['1961'], bar_width, color= "Blue", label="1961")
end = ax.bar(index + bar_width, top_diff['2024'], bar_width, color="Purple", label="2024")

ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(top_diff['Country'], rotation=45, ha='right')

ax.set_xlabel('Country')
ax.set_ylabel('Temperature (°C)')
ax.set_title('Top 10 Countries: Temperature Increase (1961 vs 2024)')
ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(30, 30))

years = [str(year) for year in range(1961, 2025)]
for idx, row in top_diff.iterrows():
    ax.plot(years, row[years], label=row['Country'])

ax.set_xlabel('Year')
ax.set_ylabel('Temperature (°C)')
ax.set_title('Temperature Change (1961-2024) for Top 10 Countries')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))

plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
