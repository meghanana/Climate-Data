# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv')

# %%
df_us = df[df['Country'] == 'United States']

# %%
import pandas as pd

# Example dataset
data = {
    'Country': ['United States', 'Canada', 'United States', 'Mexico'],
    'Temperature': [65, 45, 68, 70]
}

df = pd.DataFrame(data)

# Filter for only United States
df_us = df[df['Country'] == 'United States']
print(df_us)
# Out:
#          Country  Temperature
# 0  United States           65
# 2  United States           68

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Read the CSV file
df = pd.read_csv("/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv")

#This will only take the data from United States instead of every other country 
df_us = df[df['Country'] == 'United States']

#This shows the temmperature from 1961 to 2024
year_columns = [str(year) for year in range(1961, 2024)]
data = df_us[year_columns].T  

data = data.reset_index()
data.columns = ['Year', 'Value']
data['Year'] = data['Year'].astype(int)
data['Value'] = pd.to_numeric(data['Value'], errors='coerce')


plt.figure(figsize=(20, 6))  # Wider for better label spacing
plt.plot(data['Year'], data['Value'], linestyle='-', marker='o', color='red')


plt.title('United States: Climate Change (1961–2024)', fontsize=20)
plt.xlabel('Year')
plt.xticks(data['Year'], rotation=90)
plt.ylabel('Temerature (°F)')  
plt.grid(True, linestyle='.', alpha=1)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 28
#      26 plt.xticks(data['Year'], rotation=90)
#      27 plt.ylabel('Temerature (°F)')
# ---> 28 plt.grid(True, linestyle='.', alpha=1)
#      29 plt.tight_layout()
#      30 plt.show()
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/pyplot.py:3387, in grid(visible, which, axis, **kwargs)
#    3380 @_copy_docstring_and_deprecators(Axes.grid)
#    3381 def grid(
#    3382     visible: bool | None = None,
#    (...)
#    3385     **kwargs,
#    3386 ) -> None:
# -> 3387     gca().grid(visible=visible, which=which, axis=axis, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/matplotlib/axes/_base.py:3312, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3310 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3311 if axis in ['x', 'both']:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

#Read the CSV file
df = pd.read_csv("/Users/megh/code/project/Indicator_3_1_Climate_Indicators_Annual_Mean_Global_Surface_Temperature_577579683071085080.csv")

#This will only take the data from United States instead of every other country 
df_us = df[df['Country'] == 'Mexico']

#This 
year_columns = [str(year) for year in range(1961, 2024)]
data = df_us[year_columns].T  

data = data.reset_index()
data.columns = ['Year', 'Value']
data['Year'] = data['Year'].astype(int)
data['Value'] = pd.to_numeric(data['Value'], errors='coerce')


plt.figure(figsize=(16, 6))  # Wider for better label spacing
plt.plot(data['Year'], data['Value'], linestyle='-', marker='o', color='red')


plt.title('United States: Climate Change (1961–2024)', fontsize=20)
plt.xlabel('Year')
plt.xticks(data['Year'], rotation=90)
plt.ylabel('Temerature (°F)')  
plt.grid(True, linestyle='--', alpha=1)
plt.tight_layout()
plt.show()
